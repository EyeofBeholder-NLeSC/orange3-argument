# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

fpath = '../example/data/data_processed_1prod_full.json'
df = pd.read_json(fpath, lines=True)
docs = df['reviewText'].astype(str)
type(docs)
# Out:
# pandas.core.series.Series

# %%
from orangecontrib.argument.miner.miner import chunker

docs = chunker(docs)
docs['chunk']
# Out:
# /Volumes/Databank/Workspace/orange3-argument/venv/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Volumes/Databank/Workspace/orange3-argument/venv/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
from orangecontrib.argument.miner.miner import ArguTopic

topic_model = ArguTopic()
topic_model.set_embedding_model()
topic_model.set_dimension_reduction_model()
topic_model.set_clustering_model(min_cluster_size=10)
topic_model.set_topic_conduction_models()
topic_model.build_model(reduce_topic=True)

# %%
doc_topic = topic_model.run(docs=docs['chunk'], reduce_outlier=True)

# %%
topic_model.model.get_topic_info()
# Out:
#     Topic  Count                                   Name
# 0      -1     24      -1_excelente_stylish_hope_cushion
# 1       0    321                   0_shoes_the_these_my
# 2       1    198             1_fit_size_perfect_ordered
# 3       2    127           2_comfortable_very_are_super
# 4       3     85                   3_love_them_are_they
# 5       4     53   4_purchase_product_satisfied_pleased
# 6       5     75             5_for_running_use_training
# 7       6     51         6_light_weight_lightweight_and
# 8       7     47                 7_color_the_bright_was
# 9       8     34              8_loves_she_daughter_them
# 10      9     37             9_excellent_best_nice_just
# 11     10     34                 10_run_runner_week_and
# 12     11     32                  11_day_them_wore_worn
# 13     12     35             12_support_arch_the_little
# 14     13     25  13_recommend_highly_would_recommended
# 15     14     20         14_return_liked_returning_them

# %%
topic_model.model.
# Out:
# [('shoes', 0.058015347816055766),
#  ('the', 0.03951015696673576),
#  ('these', 0.03922086073929295),
#  ('my', 0.03888913500449202),
#  ('shoe', 0.03683343921200137),
#  ('of', 0.033968212442049076),
#  ('feet', 0.03004434070111456),
#  ('for', 0.0263216589881169),
#  ('to', 0.02624216319745913),
#  ('this', 0.025275507571488855)]

# %%
from orangecontrib.argument.miner.miner import sentrank

emb = topic_model.get_doc_embed(docs['chunk'])
emb
# Out:
# array([[ 4.8847815e-01,  1.4852902e-01,  2.7672243e+00,  4.9525027e+00,
#          1.1285527e+00],
#        [ 5.9946877e-01,  6.3129801e-01,  3.2064688e+00,  4.8179612e+00,
#          5.4324114e-01],
#        [-3.6349192e-01,  2.6886771e+00,  4.0635257e+00,  5.7027531e+00,
#         -4.1833431e-05],
#        ...,
#        [ 4.2382514e-01,  2.3762107e+00,  3.6994817e+00,  4.4720607e+00,
#          6.6403067e-01],
#        [ 6.0545939e-01,  2.8851616e+00,  2.4387600e+00,  4.0977993e+00,
#          1.7243590e+00],
#        [ 9.2439669e-01,  3.9429569e+00,  1.8441002e+00,  2.8496454e+00,
#          6.6757852e-01]], dtype=float32)

# %%
sentrank(emb)
# Out:
# {0: 0.0008185015792179327,
#  1: 0.0008364776569905485,
#  2: 0.0008406519402934839,
#  3: 0.0008506693999778508,
#  4: 0.0007839172107405788,
#  5: 0.0008448460574035275,
#  6: 0.0008180325352658541,
#  7: 0.0008535017205536426,
#  8: 0.0008340672422328184,
#  9: 0.0008500368411092046,
#  10: 0.0008371215219431826,
#  11: 0.0008402342944335568,
#  12: 0.00082106462609039,
#  13: 0.0008606888231383648,
#  14: 0.000838110219786608,
#  15: 0.0008295671709507845,
#  16: 0.000808639448369046,
#  17: 0.0008501630940006082,
#  18: 0.0007872088915535776,
#  19: 0.0008349686506137086,
#  20: 0.0008422931067288756,
#  21: 0.0008572250438655082,
#  22: 0.0008338724836834685,
#  23: 0.0008165261791306282,
#  24: 0.0008416744666002851,
#  25: 0.0008397238336131434,
#  26: 0.0008290845168889188,
#  27: 0.0008323616529467695,
#  28: 0.0008598304402889093,
#  29: 0.0008307038885112945,
#  30: 0.000827783166874853,
#  31: 0.0008543316235259091,
#  32: 0.0008118465191782663,
# ...
