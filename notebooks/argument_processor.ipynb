# %%
from orangecontrib.argument.miner.miner import ArgumentProcessor
import pandas as pd

fpath = '../example/data/data_processed_1prod_sample.json'

df = pd.read_json(fpath, lines=True)

# %%
df.rename({'reviewText': 'argument'}, axis=1, inplace=True)

# %%
ap = ArgumentProcessor(df)

# %%
ap.compute_textrank()
ap.df
# Out:
#                                              argument  overall  \
# 0   Returning these. the pictures on here make the...        1
# 1   After using this shoes seven times for regular...        1
# 2   After less than a week the sole ripped off on ...        1
# 3                                         wrong shoes        1
# 4   I wore these shoe one time, from the airport i...        1
# 5   I returned these as they were not true to size...        2
# 6   Color was not at all what i expected.  It was ...        2
# 7   Tried one in the store and bought it online bu...        2
# 8   I've always gotten this size in Nike shoes wit...        2
# 9   These shoes are poorly constructed and I don't...        2
# 10  Super light and very comfortable. I'm a runner...        3
# 11  On the left shoe, there were two stained yello...        3
# 12  This is a shoe I will wear with black dress pa...        3
# 13  These are a bit longer than they should be. I ...        3
# 14  Super cute shoe however runs wide and big, I'm...        3
# 15  Very comfortable sneakers and I also like the ...        4
# 16  Comfortable athletic shoe,  good for the gym (...        4
# 17                                  Very comfortable.        4
# 18  Perfect for the gym, could use a little more s...        4
# 19  I was really excited when I opened the box to ...        4
# 20  Very comfortable shoes. I have wide feet with ...        5
# 21  Love them! Fit exactly as expected in length a...        5
# 22  Ordered half a size larger than my usual shoe ...        5
# 23                        My favorite cross trainers!        5
# 24  My knees were bothering me during HIIT workout...        5
#
#                                                 ranks
# 0   [(flex supreme tr3, 0.17808456809142034), (pin...
# 1   [(regular activities, 0.14399315659949094), (r...
# 2   [(shoe, 0.13625347940334348), (outside, 0.1039...
# 3                 [(wrong shoes, 0.4714045207910316)]
# 4   [(phoenix, 0.13682340641174387), (az, 0.120526...
# 5                       [(size, 0.28862962196165753)]
# 6                      [(color, 0.15241892546418206)]
# 7   [(shoe, 0.2208104360870024), (big , different ...
# 8   [(similar description, 0.21745604149880265), (...
# 9   [(nike downshifter series, 0.15949716478291207...
# 10  [(arch support, 0.16088709356961922), (super l...
# 11  [(stained yellow spots, 0.21501619821488355), ...
# 12  [(little support, 0.1806453073254181), (black ...
# 13  [(opposite, 0.16701178903920144), (, 0.1491339...
# 14  [(size, 0.1375393817949753), (size, 0.13753938...
# 15  [(comfortable sneakers, 0.1500513316982913), (...
# 16  [(tredmill, 0.22225538408029755), (comfortable...
# 17                                                 []
# 18  [(size, 0.14025088069894592), (little support,...
# 19  [(flex tr, 0.14042666297974274), (image shows,...
# 20  [(falling arches, 0.2946349732509538), (wide f...
# 21  [(width, 0.29845549710341956), (length, 0.2194...
# 22            [(usual shoe size, 0.1952589819807094)]
# 23   [(favorite cross trainers, 0.25555062599997597)]
# 24  [(styles, 0.24022720602123782), (hiit workouts...

# %%
ap.compute_readability()
ap.df
# Out:
#                                              argument  overall  \
# 0   Returning these. the pictures on here make the...        1
# 1   After using this shoes seven times for regular...        1
# 2   After less than a week the sole ripped off on ...        1
# 3                                         wrong shoes        1
# 4   I wore these shoe one time, from the airport i...        1
# 5   I returned these as they were not true to size...        2
# 6   Color was not at all what i expected.  It was ...        2
# 7   Tried one in the store and bought it online bu...        2
# 8   I've always gotten this size in Nike shoes wit...        2
# 9   These shoes are poorly constructed and I don't...        2
# 10  Super light and very comfortable. I'm a runner...        3
# 11  On the left shoe, there were two stained yello...        3
# 12  This is a shoe I will wear with black dress pa...        3
# 13  These are a bit longer than they should be. I ...        3
# 14  Super cute shoe however runs wide and big, I'm...        3
# 15  Very comfortable sneakers and I also like the ...        4
# 16  Comfortable athletic shoe,  good for the gym (...        4
# 17                                  Very comfortable.        4
# 18  Perfect for the gym, could use a little more s...        4
# 19  I was really excited when I opened the box to ...        4
# 20  Very comfortable shoes. I have wide feet with ...        5
# 21  Love them! Fit exactly as expected in length a...        5
# 22  Ordered half a size larger than my usual shoe ...        5
# 23                        My favorite cross trainers!        5
# 24  My knees were bothering me during HIIT workout...        5
#
#                                                 ranks  readability
# 0   [(flex supreme tr3, 0.17808456809142034), (pin...     8.189923
# 1   [(regular activities, 0.14399315659949094), (r...     7.287456
# 2   [(shoe, 0.13625347940334348), (outside, 0.1039...     8.220154
# 3                 [(wrong shoes, 0.4714045207910316)]    10.000000
# 4   [(phoenix, 0.13682340641174387), (az, 0.120526...     7.532680
# 5                       [(size, 0.28862962196165753)]     8.960822
# 6                      [(color, 0.15241892546418206)]     9.220075
# 7   [(shoe, 0.2208104360870024), (big , different ...     8.770972
# 8   [(similar description, 0.21745604149880265), (...     7.436600
# 9   [(nike downshifter series, 0.15949716478291207...     6.836355
# 10  [(arch support, 0.16088709356961922), (super l...     7.872340
# 11  [(stained yellow spots, 0.21501619821488355), ...     8.520095
# 12  [(little support, 0.1806453073254181), (black ...     8.212513
# 13  [(opposite, 0.16701178903920144), (, 0.1491339...     8.013908
# 14  [(size, 0.1375393817949753), (size, 0.13753938...     7.820272
# 15  [(comfortable sneakers, 0.1500513316982913), (...     7.062769
# 16  [(tredmill, 0.22225538408029755), (comfortable...     6.632958
# 17                                                 []     0.000000
# 18  [(size, 0.14025088069894592), (little support,...     7.473591
# 19  [(flex tr, 0.14042666297974274), (image shows,...     7.535604
# 20  [(falling arches, 0.2946349732509538), (wide f...     7.677002
# 21  [(width, 0.29845549710341956), (length, 0.2194...     7.612539
# 22            [(usual shoe size, 0.1952589819807094)]     7.417053
# 23   [(favorite cross trainers, 0.25555062599997597)]     6.130024
# 24  [(styles, 0.24022720602123782), (hiit workouts...     8.656767

# %%
ap.compute_sentiment()
ap.df
# Out:
#                                              argument  overall  \
# 0   Returning these. the pictures on here make the...        1
# 1   After using this shoes seven times for regular...        1
# 2   After less than a week the sole ripped off on ...        1
# 3                                         wrong shoes        1
# 4   I wore these shoe one time, from the airport i...        1
# 5   I returned these as they were not true to size...        2
# 6   Color was not at all what i expected.  It was ...        2
# 7   Tried one in the store and bought it online bu...        2
# 8   I've always gotten this size in Nike shoes wit...        2
# 9   These shoes are poorly constructed and I don't...        2
# 10  Super light and very comfortable. I'm a runner...        3
# 11  On the left shoe, there were two stained yello...        3
# 12  This is a shoe I will wear with black dress pa...        3
# 13  These are a bit longer than they should be. I ...        3
# 14  Super cute shoe however runs wide and big, I'm...        3
# 15  Very comfortable sneakers and I also like the ...        4
# 16  Comfortable athletic shoe,  good for the gym (...        4
# 17                                  Very comfortable.        4
# 18  Perfect for the gym, could use a little more s...        4
# 19  I was really excited when I opened the box to ...        4
# 20  Very comfortable shoes. I have wide feet with ...        5
# 21  Love them! Fit exactly as expected in length a...        5
# 22  Ordered half a size larger than my usual shoe ...        5
# 23                        My favorite cross trainers!        5
# 24  My knees were bothering me during HIIT workout...        5
#
#                                                 ranks  readability  sentiment
# 0   [(flex supreme tr3, 0.17808456809142034), (pin...     8.189923         -1
# 1   [(regular activities, 0.14399315659949094), (r...     7.287456         -1
# 2   [(shoe, 0.13625347940334348), (outside, 0.1039...     8.220154         -1
# 3                 [(wrong shoes, 0.4714045207910316)]    10.000000         -1
# 4   [(phoenix, 0.13682340641174387), (az, 0.120526...     7.532680         -1
# 5                       [(size, 0.28862962196165753)]     8.960822         -1
# 6                      [(color, 0.15241892546418206)]     9.220075         -1
# 7   [(shoe, 0.2208104360870024), (big , different ...     8.770972         -1
# 8   [(similar description, 0.21745604149880265), (...     7.436600         -1
# 9   [(nike downshifter series, 0.15949716478291207...     6.836355         -1
# 10  [(arch support, 0.16088709356961922), (super l...     7.872340          1
# 11  [(stained yellow spots, 0.21501619821488355), ...     8.520095         -1
# 12  [(little support, 0.1806453073254181), (black ...     8.212513         -1
# 13  [(opposite, 0.16701178903920144), (, 0.1491339...     8.013908         -1
# 14  [(size, 0.1375393817949753), (size, 0.13753938...     7.820272         -1
# 15  [(comfortable sneakers, 0.1500513316982913), (...     7.062769          1
# 16  [(tredmill, 0.22225538408029755), (comfortable...     6.632958          1
# 17                                                 []     0.000000          1
# 18  [(size, 0.14025088069894592), (little support,...     7.473591          1
# 19  [(flex tr, 0.14042666297974274), (image shows,...     7.535604          1
# 20  [(falling arches, 0.2946349732509538), (wide f...     7.677002          1
# 21  [(width, 0.29845549710341956), (length, 0.2194...     7.612539          1
# 22            [(usual shoe size, 0.1952589819807094)]     7.417053          1
# 23   [(favorite cross trainers, 0.25555062599997597)]     6.130024          1
# 24  [(styles, 0.24022720602123782), (hiit workouts...     8.656767          1

# %%
from flair.nn import Classifier
from flair.data import Sentence

# load the model
tagger = Classifier.load('sentiment')

# make a sentence
sentence = Sentence('This movie is not at all bad.')

# predict NER tags
tagger.predict(sentence)

# print sentence with predicted tags
print(sentence)
# Out:
# Sentence[8]: "This movie is not at all bad." → POSITIVE (0.9929)

# %%
from flair.models import TARSClassifier
from flair.data import Sentence

# 1. Load our pre-trained TARS model for English
tars = TARSClassifier.load('tars-base')

# 2. Prepare some test sentences
sentences = [Sentence("I am so glad you like burritos!"), Sentence("Burritos are ok."), Sentence("I hate burritos.")]

# 3. Predict zero-shot for classes "positive", "negative" and "neutral" and print results
labels = ["positive sentiment", "negative sentiment", "neutral sentiment"]

for sentence in sentences:
    tars.predict_zero_shot(sentence, labels)
    print(sentence) 
    break
# Out:
# 2023-04-05 16:43:09,194 TARS initialized without a task. You need to call .add_and_switch_to_new_task() before training this model
# 2023-04-05 16:43:09,381 Provided `None` does not exist in the model. Consider calling `add_and_switch_to_new_task` first.
# 2023-04-05 16:43:09,382 `ZeroShot` is the current task. Switch to some other task before dropping this.
# Sentence[8]: "I am so glad you like burritos!"
